# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

img = cv.imread('../images/image2.jpeg', 0)

# Plot the original image
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(img)

if img is not None and img.shape[0] > 300 and img.shape[1] > 100:
    cropped_img = img[450:350, 100:400]

# Plot the original image
    plt.subplot(1,2,2)
    plt.title("Cropped Image")
    plt.imshow(cropped_img)

    cv.imwrite('cropped_out.jpg', cropped_img)
else:
    print(img.shape[1])
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# /var/folders/hs/30fs2wcd11vc1118kmyx5shm0000gn/T/ipykernel_8788/2912701263.py:18: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.imshow(cropped_img)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 20
#      17     plt.title("Cropped Image")
#      18     plt.imshow(cropped_img)
# ---> 20     cv.imwrite('cropped_out.jpg', cropped_img)
#      21 else:
#      22     print(img.shape[1])
#
# error: OpenCV(4.11.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:929: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
