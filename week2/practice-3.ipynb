# %% [markdown]
# ## Adjusting Brightness and Contrast

# %%
import cv2;
import matplotlib.pyplot as plt;
import numpy as np;

image = cv2.imread("../images/image.jpeg")

plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(image)

# Adjusting the brightness and contrast of the image
brightness = 5
contrast = 1.5
image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape, image.dtype), 0, brightness)

# Save the image
cv2.imwrite('images/edited_image.jpeg', image2)
# Plot the edited image
plt.subplot(1,2,2)
plt.title("Edited Image")
plt.imshow(image2)
plt.show()
